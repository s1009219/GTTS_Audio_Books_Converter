# %% [markdown]
# <a href="https://colab.research.google.com/github/s1009219/GTTS_Audio_Books_Converter/blob/main/Audio_Books_Converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Drafts

from gtts import gTTS
import os
tts = gTTS(text='Good morning', lang='en')
tts.save("good.mp3")

###page = pdfReader.getpages[1]
###text = page.extracText()
book = open('Book1.pdf','rb')

for pages in range(5,10):
  page = pdfReader.pages[pages]
  text = page.extract_text()
tts = gTTS(text, lang='en')
tts.save("cs.mp3")
###pdfReader = PyPDF2.PdfReader(book)
###pdfReader = PyPDF2.PdfReader(book)
###Speaker = pyttsx3.init()
###Speaker.say(text)
###Speaker.runAndWait()

# %%
#Installing Packages
# !pip install pyttsx3
# !pip install PyPDF2
# !pip install gTTS

# %%
# !pip install pyttsx3
# !pip install PyPDF2
# !pip install gTTS
import PyPDF2
from gtts import gTTS
book = open('Book1.pdf','rb')
pdfReader = PyPDF2.PdfReader(book)
count = len(pdfReader.pages)
print(count)

for pages in range(len(pdfReader.pages)):
  page = pdfReader.pages[pages]
  text = page.extract_text()

tts = gTTS(text, lang='en')
tts.save("good.mp3")

from IPython.display import Audio
Audio("good.mp3")
# Out:
# ...
# 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install pyttsx3

import pyttsx3

# 初始化
engine = pyttsx3.init()

voices = engine.getProperty('voices')
# 語速控制
rate = engine.getProperty('rate')
print(rate)
engine.setProperty('rate', rate-20)

# 音量控制
volume = engine.getProperty('volume')
print(volume)
engine.setProperty('volume', volume-0.25)

engine.say('hello world')
engine.say('你好，世界')
# 朗讀一次
engine.runAndWait()

engine.say('語音合成開始')
engine.say('我會說中文了，開森，開森')
engine.runAndWait()

engine.say('The quick brown fox jumped over the lazy dog.')
engine.runAndWait()
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyttsx3/__init__.py in init(driverName, debug)
#      19     try:
# ---> 20         eng = _activeEngines[driverName]
#      21     except KeyError:
#
# /usr/lib/python3.10/weakref.py in __getitem__(self, key)
#     136             self._commit_removals()
# --> 137         o = self.data[key]()
#     138         if o is None:
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-16-8cede65a0bac> in <cell line: 6>()
#       4
#       5 # 初始化
# ----> 6 engine = pyttsx3.init()
#       7
#       8 voices = engine.getProperty('voices')
#
# /usr/local/lib/python3.10/dist-packages/pyttsx3/__init__.py in init(driverName, debug)
# ...

# %%
from gtts import gTTS
language='en'
Voice = gTTS(text="Hi",lang=language,slow=False)
Voice.save("/content/gtts.mp3")
from IPython.display import Audio
Audio("gtts.mp3")

# %%
#Finall ONE

#Packages import pip install PyPDF2, pip install gTTS
from gtts import gTTS
import PyPDF2

from tkinter.filedialog import *
###from gtts import gTTS

book = askopenfilename()
pdfReader = PyPDF2.PdfReader(book)
number_of_page = len(pdfReader.pages)
Pagenumber = print(number_of_page)

"""page = pdfReader.pages[0]
text = page.extract_text()
speech = gTTS(text, lang='en')
speech_file=speech.save("Page1.mp3")

page = pdfReader.pages[1]
text = page.extract_text()
speech = gTTS(text, lang='en')
speech_file=speech.save("Page2.mp3")"""

for num in range(0,number_of_page-1):
  String = str(num)
  page = pdfReader.pages[num]
  text = page.extract_text()
  speech = gTTS(text, lang='en')
  speech_file=speech.save("Page"+String+".mp3")
  print(num)

print("Finish!!!")
